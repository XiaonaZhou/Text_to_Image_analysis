# %% [markdown]
# # Extract faces from COCO

# %% [markdown]
# This notebook shows how I extract faces from COCO dataset for Text-to-Image model analysis.

# %% [markdown]
# ## Step 1: Load COCO dataset

# %% [markdown]
# By referencing [this notebook](https://github.com/ntrang086/image_captioning/blob/master/0_Dataset.ipynb), we loaded the dataset

# %%
#!pip install pycocotools
import io
import os
from pycocotools.coco import COCO
from PIL import Image
import matplotlib.pyplot as plt

# initialize COCO API for instance annotations
dataDir = '.'
dataType = 'train2017'
instances_annFile = os.path.join(dataDir, 'cocoapi/annotations/instances_{}.json'.format(dataType))
coco = COCO(instances_annFile)

# initialize COCO API for caption annotations
captions_annFile = os.path.join(dataDir, 'cocoapi/annotations/captions_{}.json'.format(dataType))
coco_caps = COCO(captions_annFile)

# get image ids 
ids = list(coco.anns.keys())
# Out:
# loading annotations into memory...
# Done (t=16.76s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.98s)
# creating index...
# index created!

# %% [markdown]
# Since we are interested in extracting faces, we filter the data by `catNm = ["person"]`.

# %%
#get Category ID of category person
person_Cat_Ids= coco.getCatIds(catNms= ["person"])

# %%
person_Cat_Ids
# Out:
# [1]

# %%
# get all images' ID  
person_image_Ids = coco.getImgIds(catIds = person_Cat_Ids)

# %%
person_image_Ids[0]
# Out:
# 262145

# %% [markdown]
# Let's see some info about the image

# %%
img_info = coco.loadImgs(person_image_Ids[5])[0]

# %%
img_info
# Out:
# {'license': 2,
#  'file_name': '000000393224.jpg',
#  'coco_url': 'http://images.cocodataset.org/train2017/000000393224.jpg',
#  'height': 640,
#  'width': 427,
#  'date_captured': '2013-11-18 02:29:39',
#  'flickr_url': 'http://farm9.staticflickr.com/8503/8356977703_647d20f05c_z.jpg',
#  'id': 393224}

# %%
# total number of images 
len(person_image_Ids)
# Out:
# 64115

# %% [markdown]
# Display one image. Note: not all the images contain face(s).

# %%
# load image from file
image = Image.open(os.path.join('./cocoapi/images/train2017',img_info['file_name']))

# convert to RGB, if needed
# We have a colored image, the code below does not change the image
#image = image.convert('RGB')
plt.imshow(image)

# %% [markdown]
# ## Step 2: Define face detector

# %% [markdown]
# We used a face recognition system introduced in this [post](https://machinelearningmastery.com/how-to-develop-a-face-recognition-system-using-facenet-in-keras-and-an-svm-classifier/)

# %%
# install all packages
from keras.models import load_model
# !pip install mtcnn
# confirm mtcnn was installed correctly
import mtcnn
# print version
print(mtcnn.__version__)

import numpy as np
from mtcnn.mtcnn import MTCNN
from numpy import asarray


# Simple python package to shut up Tensorflow warnings and logs.
# !pip install silence_tensorflow
import silence_tensorflow.auto
# Out:
# 2022-11-24 10:13:26.131304: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-24 10:13:33.580904: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-24 10:13:33.580995: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %% [markdown]
# Define a function that extract a single face from a given image if the confidence (the confidence that a face is detected) is greater than a given threshold.

# %%
# extract a single face from a given photograph
def extract_face(filename, index, required_size=(250, 250), threshold = 0.99):
    # load image from file
    image = Image.open(filename)
    # convert to RGB, if needed
    image = image.convert('RGB')
    # convert to array
    pixels = np.asarray(image)
    # create the detector, using default weights
    detector = MTCNN()
    # detect faces in the image
    results = detector.detect_faces(pixels)
    # extract the bounding box from the first face
    if len(results) >=1 and results[0]['confidence'] >= threshold:
        x1, y1, width, height = results[0]['box']
        if height-width>=15:
            # bug fix
            x1, y1 = abs(x1), abs(y1)
            x2, y2 = x1 + width, y1 + height
            # extract the face
            face = pixels[y1:y2, x1:x2]
            # resize pixels to the model size
            image = Image.fromarray(face)
            image = image.resize(required_size)
            face_array = np.asarray(image)
            plt.imsave(os.path.join(savedirimage, 'face_img_{}.jpg'.format(index)),face_array)
            return True
    return False

# %%
#set up folders for extracted faces and the corresponding captions 
# initialize COCO API for instance annotations
dataDir = './'

image_folder = "extracted_faces"

savedirimage = dataDir + "cocoapi/images/" + image_folder + "/"

captionfilename = dataDir + "cocoapi/images/face_captions.txt"


if not os.path.exists(savedirimage):
	os.makedirs(savedirimage)

# %% [markdown]
# ## Step 3: extract faces from COCO dataset

# %% [markdown]
# I first tried to extract 10k faces at once, but that took too long. Therefore, I modified the code below so I can extract faces in small intervals.

# %%
# index = 0
# captionfile = open(captionfilename, "w")
# for i in range(len(person_image_Ids)):
#     img_info = coco.loadImgs(person_image_Ids[i])[0]
#     if extract_face(os.path.join('./cocoapi/images/train2017',img_info['file_name']), index ):
#         annIds = coco_caps.getAnnIds(imgIds=img_info['id'])
#         anns = coco_caps.loadAnns(annIds)
#         #print(coco_caps.showAnns(anns))
    
#         cap_index = 4 # Choosing 5th caption
#         caption = anns[cap_index]['caption']
#         captionfile.write(caption + '\n')
#         index+=1
# captionfile.close()

# %%
index = 9853 # keep track of how many faces has been extracted
captionfile = open(captionfilename, "a")
for i in range(64101,64115):
    img_info = coco.loadImgs(person_image_Ids[i])[0]
    if extract_face(os.path.join('./cocoapi/images/train2017',img_info['file_name']), index ) and index <10000:
        annIds = coco_caps.getAnnIds(imgIds=img_info['id'])
        anns = coco_caps.loadAnns(annIds)
        #print(coco_caps.showAnns(anns))
    
        cap_index = 4 # Choosing 5th caption
        caption = anns[cap_index]['caption']
        captionfile.write(caption + '\n')
        index+=1
        print('------------'+str(i)+'----------------')
captionfile.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [12], line 4
#       2 captionfile = open(captionfilename, "a")
#       3 for i in range(64101,64115):
# ----> 4     img_info = coco.loadImgs(person_image_Ids[i])[0]
#       5     if extract_face(os.path.join('./cocoapi/images/train2017',img_info['file_name']), index ) and index <10000:
#       6         annIds = coco_caps.getAnnIds(imgIds=img_info['id'])
#
# IndexError: list index out of range

# %% [markdown]
# Check index, i, reset index and i on the code chuck above after each interval.

# %%
index
# Out:
# 9853

# %%
i
# Out:
# 64114

# %% [markdown]
# Used all the images in train2017, only 9854 images quaified. Using train2014 for the rest of 146 images.

# %%
#!pip install pycocotools
import io
import os
from pycocotools.coco import COCO
from PIL import Image
import matplotlib.pyplot as plt
# initialize COCO API for instance annotations
dataDir = '.'
dataType = 'train2014'
instances_annFile = os.path.join(dataDir, 'cocoapi/annotations_2014/instances_{}.json'.format(dataType))
coco = COCO(instances_annFile)

# initialize COCO API for caption annotations
captions_annFile = os.path.join(dataDir, 'cocoapi/annotations_2014/captions_{}.json'.format(dataType))
coco_caps = COCO(captions_annFile)

# get image ids 
ids = list(coco.anns.keys())
# Out:
# loading annotations into memory...
# Done (t=11.49s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.56s)
# creating index...
# index created!

# %%
#get Category ID of category person
person_Cat_Ids= coco.getCatIds(catNms= ["person"])

# %%
# get all images' ID  
person_image_Ids = coco.getImgIds(catIds = person_Cat_Ids)

# %%
# total number of images 
len(person_image_Ids)
# Out:
# 45174

# %%
index = 10000
#captionfile = open(captionfilename, "a")
for i in range(len(person_image_Ids)):
    img_info = coco.loadImgs(person_image_Ids[i])[0]
    if extract_face(os.path.join('./cocoapi/images/train2014',img_info['file_name']), index ) and index <10007:
        annIds = coco_caps.getAnnIds(imgIds=img_info['id'])
        anns = coco_caps.loadAnns(annIds)
        #print(coco_caps.showAnns(anns))
    
        cap_index = 4 # Choosing 5th caption
        caption = anns[cap_index]['caption']
        #captionfile.write(caption + '\n')
        index+=1
        print('------------'+str(i)+'----------------')
captionfile.close()
# Out:
# ...
# 1/1 [==============================] - 0s 163ms/step
# ------------3----------------
# ...
# 1/1 [==============================] - 0s 171ms/step
# ------------4----------------
# ...
# 2/2 [==============================] - 0s 12ms/step
# ------------10----------------
# ...
# 1/1 [==============================] - 0s 223ms/step
# ------------13----------------
# ...
# 1/1 [==============================] - 0s 201ms/step
# ------------14----------------
# ...
# 2/2 [==============================] - 0s 11ms/step
# ------------16----------------
# ...
# 1/1 [==============================] - 0s 177ms/step
# ------------17----------------
# ...
# 2/2 [==============================] - 0s 8ms/step
# ...
# ...
# 1/3 [=========>....................] - ETA: 0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [43], line 5
#       3 for i in range(len(person_image_Ids)):
# ...

# %%
index
# Out:
# 10000

# %%
captionfile.close()

# %% [markdown]
# #### Little trick that improve the quality of faces extracted

# %%
# test out what would be a good width and height for a face that is clear enough
# I think it should be at least 15
'''
img_info = coco.loadImgs(person_image_Ids[11])[0]
file_name = os.path.join('./cocoapi/images/train2017',img_info['file_name'])
image = Image.open(file_name)
plt.imshow(image)
# convert to RGB, if needed
image = image.convert('RGB')
# convert to array
pixels = np.asarray(image)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
results = detector.detect_faces(pixels)
img_info = coco.loadImgs(person_image_Ids[5])[0]
print(img_info['file_name'])
# load image from file
results
x1, y1, width, height = results[0]['box']
# bug fix
x1, y1 = abs(x1), abs(y1)
x2, y2 = x1 + width, y1 + height
# extract the face
face = pixels[y1:y2, x1:x2]
#plt.imshow(face)
'''
# Out:
# ...
# 1/1 [==============================] - 0s 164ms/step
# 000000393224.jpg

# %% [markdown]
# I first tried using val2017, but there's very few good face images.

# %%
'''
index = 9853
captionfile = open(captionfilename, "a")
for i in range(0, len(person_image_Ids)):
    img_info = coco.loadImgs(person_image_Ids[i])[0]
    if extract_face(os.path.join('./cocoapi/images/val2017',img_info['file_name']), index ) and index <10000:
        annIds = coco_caps.getAnnIds(imgIds=img_info['id'])
        anns = coco_caps.loadAnns(annIds)
        #print(coco_caps.showAnns(anns))
    
        cap_index = 4 # Choosing 5th caption
        caption = anns[cap_index]['caption']
        captionfile.write(caption + '\n')
        index+=1
        print('------------'+str(i)+'----------------')
captionfile.close()
'''
# Out:
# ...
# 1/1 [==============================] - 0s 188ms/step
# ------------11----------------
# ...
# 1/1 [==============================] - 0s 181ms/step
# ------------12----------------
# ...
# 1/1 [==============================] - 0s 144ms/step
# ------------37----------------
# ...
# 1/1 [==============================] - 0s 143ms/step
# ------------41----------------
# ...
# 2/2 [==============================] - 0s 11ms/step
# ------------46----------------
# ...
# 1/1 [==============================] - 0s 131ms/step
# ------------47----------------
# ...
# 1/1 [==============================] - 0s 131ms/step
# ------------56----------------
# ...
# 1/1 [==============================] - 0s 129ms/step
# ------------61----------------
# ...
# 1/1 [==============================] - 0s 131ms/step
# ------------65----------------
# ...
# 1/1 [==============================] - 0s 132ms/step
# ------------66----------------
# ...
# 1/1 [==============================] - 0s 127ms/step
# ------------68----------------
# ...
